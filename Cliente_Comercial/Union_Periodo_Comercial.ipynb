# %%
import numpy as np
import pandas as pd

# %%
hubbay_df = pd.read_excel('HUDBAY.xlsx')
hubbay_df.head()
# Out:
#    IdServicio  IdConductor  IdMovil GrupoNegocio PlacaAuto ModeloAuto  \
# 0     2816692       1456.0   1456.0      DESTINO    BWW418       RUSH
# 1     2814831        404.0    404.0      DESTINO    BJJ600         F3
# 2     2811131       2010.0   2010.0      DESTINO    BVP613  GLORY 580
# 3     2819861        571.0    571.0      DESTINO    BMQ637  GLORY 560
# 4     2807705       1424.0   1424.0      DESTINO    Y2A465       CX70
#
#                           Conductor      Fecha_Servicio  \
# 0        ACOSTA RODRIGUEZ JOSE LUIS 2023-01-01 06:00:00
# 1         ANCASI ROJAS PERCY ANDREE 2023-01-02 03:30:00
# 2    RIVAS MOSCOSO ALEXANDER YAMILL 2023-01-02 04:40:00
# 3  PETRUCCELLI CONDOR CESAR AUGUSTO 2023-01-02 04:50:00
# 4              SARMIENTO VIDAL RAUL 2023-01-02 05:30:00
#
#            Fecha_Asignado           Fecha_Lectura  ... Total Propina  \
# 0 2023-01-01 05:09:47.877 2023-01-01 05:09:55.237  ...             0
# ...

# %%
prueba_df = pd.read_excel('prueba.xlsx')
prueba_df.head()
# Out:
#    Unnamed: 0           Unnamed: 1   Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN  Reporte de Finanzas          NaN         NaN         NaN
# 1         NaN                  NaN          NaN         NaN         NaN
# 2         NaN           IdServicio  IdConductor       Flota   Membresía
# 3         NaN              5326727         2970  Aeropuerto         NaN
# 4         NaN              5327284         9740      Urbano  PARTNER V1
#
#   Unnamed: 5 Unnamed: 6  Unnamed: 7                       Unnamed: 8  \
# 0        NaN        NaN         NaN                              NaN
# 1        NaN        NaN         NaN                              NaN
# 2    IdMovil  PlacaAuto  ModeloAuto                        Conductor
# 3       2970     CSH510      REFINE  JEFFERSON REBER DE LA CRUZ INGA
# 4       9740     BMK019        RUSH      JORGE LUIS ESTELA COARICONA
#
#             Unnamed: 9  ... Unnamed: 126  Unnamed: 127       Unnamed: 128  \
# ...

# %%
prueba_df = prueba_df.drop(index={0,1}, inplace=True)
prueba_df.drop('Unnamed: 0', axis=1, inplace=True)
prueba_df.head()

# %%
prueba_df.columns = prueba_df.iloc[0]
prueba_df.head()
# Out:
# 2  IdServicio  IdConductor       Flota   Membresía  IdMovil  PlacaAuto  \
# 2  IdServicio  IdConductor       Flota   Membresía  IdMovil  PlacaAuto
# 3     5326727         2970  Aeropuerto         NaN     2970     CSH510
# 4     5327284         9740      Urbano  PARTNER V1     9740     BMK019
# 5     5323054          NaN         NaN         NaN      NaN        NaN
# 6     5323052         1844    JetSmart         NaN     1844     CPV632
#
# 2  ModeloAuto                        Conductor       Fecha_Servicio  \
# 2  ModeloAuto                        Conductor       Fecha_Servicio
# 3      REFINE  JEFFERSON REBER DE LA CRUZ INGA  2025-11-01 00:00:00
# 4        RUSH      JORGE LUIS ESTELA COARICONA  2025-11-01 00:00:00
# 5         NaN                              NaN  2025-11-01 00:00:00
# 6       RAIZE   JOSÉ ALBERTO BETANCOURT CAMPOS  2025-11-01 00:00:00
#
# 2  Hora_Servicio  ...  Maletera  FacturaEnvio  NroDocumentoEnvio  \
# ...

# %%
prueba_df.drop(index=2, inplace = True)
prueba_df.head()
# Out:
# 2 IdServicio IdConductor       Flota   Membresía IdMovil PlacaAuto ModeloAuto  \
# 3    5326727        2970  Aeropuerto         NaN    2970    CSH510     REFINE
# 4    5327284        9740      Urbano  PARTNER V1    9740    BMK019       RUSH
# 5    5323054         NaN         NaN         NaN     NaN       NaN        NaN
# 6    5323052        1844    JetSmart         NaN    1844    CPV632      RAIZE
# 7    5283088         251  Aeropuerto   REGULAR 3     251    BEI573      ETIOS
#
# 2                        Conductor       Fecha_Servicio Hora_Servicio  ...  \
# 3  JEFFERSON REBER DE LA CRUZ INGA  2025-11-01 00:00:00      03:00:00  ...
# 4      JORGE LUIS ESTELA COARICONA  2025-11-01 00:00:00      03:00:00  ...
# 5                              NaN  2025-11-01 00:00:00      03:45:00  ...
# 6   JOSÉ ALBERTO BETANCOURT CAMPOS  2025-11-01 00:00:00      04:20:00  ...
# 7  ALEX ADRIAN DE LA CRUZ YUPANQUI  2025-11-01 00:00:00      05:15:00  ...
#
# ...

# %%
prueba_df.tail()
# Out:
# 2   IdServicio IdConductor       Flota  Membresía IdMovil PlacaAuto  \
# 857    5363633         754  Aeropuerto  REGULAR 3     754    AWS012
# 858    5385116         858  Aeropuerto  REGULAR 1     858    CTI293
# 859    5385446         830  Aeropuerto  REGULAR 2     830    CBC085
# 860    5385632        3974  Aeropuerto        NaN    3974    CUT292
# 861    5385688         207  Aeropuerto  REGULAR 1     207    CRT364
#
# 2       ModeloAuto                    Conductor       Fecha_Servicio  \
# 857          VERSA    CASTILLO RUPAY JHON ERICK  2025-11-30 00:00:00
# 858  XPANDER CROSS  GLORIA VILLANUEVA TORREALVA  2025-11-30 00:00:00
# 859       GLORY580       JERONIMO INGA ESPINOZA  2025-11-30 00:00:00
# 860        COROLLA         Wileam Aquino Huaire  2025-11-30 00:00:00
# 861         AVANZA         CESAR LENGUA DONAYRE  2025-11-30 00:00:00
#
# 2   Hora_Servicio  ... Maletera FacturaEnvio NroDocumentoEnvio Ticket Counter  \
# ...

# %%
union_df = pd.concat([hubbay_df, prueba_df], axis=1)
union_df.head()
# Out:
#    IdServicio  IdConductor  IdMovil GrupoNegocio PlacaAuto ModeloAuto  \
# 0     2816692       1456.0   1456.0      DESTINO    BWW418       RUSH
# 1     2814831        404.0    404.0      DESTINO    BJJ600         F3
# 2     2811131       2010.0   2010.0      DESTINO    BVP613  GLORY 580
# 3     2819861        571.0    571.0      DESTINO    BMQ637  GLORY 560
# 4     2807705       1424.0   1424.0      DESTINO    Y2A465       CX70
#
#                           Conductor      Fecha_Servicio  \
# 0        ACOSTA RODRIGUEZ JOSE LUIS 2023-01-01 06:00:00
# 1         ANCASI ROJAS PERCY ANDREE 2023-01-02 03:30:00
# 2    RIVAS MOSCOSO ALEXANDER YAMILL 2023-01-02 04:40:00
# 3  PETRUCCELLI CONDOR CESAR AUGUSTO 2023-01-02 04:50:00
# 4              SARMIENTO VIDAL RAUL 2023-01-02 05:30:00
#
#            Fecha_Asignado           Fecha_Lectura  ... Maletera FacturaEnvio  \
# 0 2023-01-01 05:09:47.877 2023-01-01 05:09:55.237  ...      NaN          NaN
# ...
